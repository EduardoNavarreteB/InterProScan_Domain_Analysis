# %%
#imports
import networkx as nx
import fastobo
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
from networkx.drawing.nx_agraph import graphviz_layout

# %%
obo = fastobo.load('go-basic.obo')
knowledge_graph = nx.DiGraph()

# %%
for frame in obo:
    if isinstance(frame, fastobo.term.TermFrame):
        name=str(frame[0]).replace('namespace: ', '')
        knowledge_graph.add_node(str(frame.id), NAME=name)
    for clause in frame:
        if isinstance(clause, fastobo.term.IsAClause):
            knowledge_graph.add_edge(str(frame.id), str(clause.term))

# %%
nx.is_directed_acyclic_graph(knowledge_graph)
# Out:
# True

# %%
with open('put_reg_go.txt', 'r') as go:
    gos = go.readlines()
    regulatory_gos = [i.replace('\n', '') for i in gos]
    print(len(regulatory_gos),regulatory_gos)
# Out:
# 384 ['GO:0003714', 'GO:0003916', 'GO:0045340', 'GO:0001965', 'GO:0032266', 'GO:0016722', 'GO:0005981', 'GO:0006952', 'GO:0060962', 'GO:1990226', 'GO:0000127', 'GO:0016567', 'GO:0005634', 'GO:0006391', 'GO:0006959', 'GO:0034246', 'GO:0016790', 'GO:0032007', 'GO:0019629', 'GO:0030527', 'GO:0006310', 'GO:0006351', 'GO:0016151', 'GO:0005952', 'GO:0009986', 'GO:0040008', 'GO:0009432', 'GO:0000774', 'GO:0050262', 'GO:0009788', 'GO:0003899', 'GO:0005882', 'GO:0004674', 'GO:0009435', 'GO:0044325', 'GO:0035198', 'GO:0000160', 'GO:0043248', 'GO:0031124', 'GO:0030915', 'GO:0071467', 'GO:0009960', 'GO:0047286', 'GO:0043047', 'GO:0000439', 'GO:0008324', 'GO:0019348', 'GO:0019217', 'GO:0033209', 'GO:0000123', 'GO:0005940', 'GO:0007275', 'GO:0007008', 'GO:0005667', 'GO:0021778', 'GO:0006357', 'GO:0051775', 'GO:0007165', 'GO:0010923', 'GO:0006808', 'GO:0000977', 'GO:0031638', 'GO:0006338', 'GO:0005858', 'GO:0051252', 'GO:0003676', 'GO:0008270', 'GO:0008289', 'GO:0000978', 'GO:0035556', 'GO:0006897', 'GO:0007283', 'GO:0005689', 'GO:0043565', 'GO:0004523', 'GO:0036444', 'GO:0045737', 'GO:0006888', 'GO:0016538', 'GO:0010090', 'GO:0032297', 'GO:0006750', 'GO:0016540', 'GO:0008907', 'GO:0016602', 'GO:0035307', 'GO:1901894', 'GO:1900111', 'GO:0045670', 'GO:0043087', 'GO:0050434', 'GO:0008233', 'GO:0051087', 'GO:0006268', 'GO:0070682', 'GO:0003723', 'GO:0045116', 'GO:0090729', 'GO:0000781', 'GO:0009966', 'GO:0060340', 'GO:0004842', 'GO:0004659', 'GO:0070530', 'GO:0031507', 'GO:0016575', 'GO:0043130', 'GO:0016571', 'GO:0000159', 'GO:0035226', 'GO:0042025', 'GO:0004521', 'GO:0000164', 'GO:0016776', 'GO:0004519', 'GO:0006396', 'GO:0000921', 'GO:0019901', 'GO:0031449', 'GO:0070449', 'GO:0003690', 'GO:0009378', 'GO:0000981', 'GO:0005739', 'GO:0000150', 'GO:0005643', 'GO:0000166', 'GO:0031047', 'GO:0005829', 'GO:0000724', 'GO:0045122', 'GO:0003887', 'GO:0008988', 'GO:0006109', 'GO:0019208', 'GO:0071595', 'GO:0048203', 'GO:0030127', 'GO:0045182', 'GO:0017183', 'GO:0001671', 'GO:0010045', 'GO:0003906', 'GO:0070824', 'GO:0080009', 'GO:0000976', 'GO:1900025', 'GO:0001216', 'GO:0030289', 'GO:0002218', 'GO:0001228', 'GO:0006402', 'GO:0006525', 'GO:0043158', 'GO:2000146', 'GO:0031348', 'GO:2000022', 'GO:0005515', 'GO:0006468', 'GO:0005524', 'GO:0006366', 'GO:0005737', 'GO:0006352', 'GO:0003700', 'GO:2000031', 'GO:0042176', 'GO:0071339', 'GO:0005672', 'GO:0019299', 'GO:0006383', 'GO:0006813', 'GO:0003917', 'GO:0000124', 'GO:0009862', 'GO:0010921', 'GO:0006284', 'GO:0045893', 'GO:0003697', 'GO:0008428', 'GO:0030154', 'GO:0000062', 'GO:0019887', 'GO:0005164', 'GO:0030145', 'GO:0003950', 'GO:0048869', 'GO:0045892', 'GO:0051606', 'GO:0009234', 'GO:0000156', 'GO:0046872', 'GO:0046278', 'GO:0009873', 'GO:0006817', 'GO:0000155', 'GO:0030374', 'GO:0045944', 'GO:0003911', 'GO:1901386', 'GO:0032088', 'GO:0034315', 'GO:0006694', 'GO:0009330', 'GO:0019619', 'GO:0003713', 'GO:0006406', 'GO:0016989', 'GO:0019210', 'GO:0009372', 'GO:0000381', 'GO:0003684', 'GO:0030238', 'GO:0003746', 'GO:0032933', 'GO:0042372', 'GO:0048578', 'GO:0006270', 'GO:0050709', 'GO:0006265', 'GO:0099402', 'GO:0031554', 'GO:0008603', 'GO:0015485', 'GO:0045600', 'GO:0006986', 'GO:0019902', 'GO:0042128', 'GO:0000502', 'GO:0005254', 'GO:0070897', 'GO:0051726', 'GO:0019867', 'GO:0009736', 'GO:0046689', 'GO:0042826', 'GO:0008277', 'GO:0016586', 'GO:0005681', 'GO:2001256', 'GO:0006367', 'GO:0000995', 'GO:0003678', 'GO:0016032', 'GO:0009909', 'GO:0005789', 'GO:0000398', 'GO:0005507', 'GO:0006281', 'GO:0003407', 'GO:0046677', 'GO:0043937', 'GO:0048658', 'GO:0006935', 'GO:0005944', 'GO:0006811', 'GO:0005096', 'GO:0000281', 'GO:0009507', 'GO:0006874', 'GO:0035650', 'GO:0005956', 'GO:0004402', 'GO:0051560', 'GO:0017025', 'GO:0016020', 'GO:0008935', 'GO:0043269', 'GO:0003712', 'GO:0019781', 'GO:0006207', 'GO:0016799', 'GO:0005085', 'GO:0044781', 'GO:0045717', 'GO:0006302', 'GO:0003896', 'GO:0000309', 'GO:0007420', 'GO:0006368', 'GO:0015689', 'GO:0000226', 'GO:0006276', 'GO:0009401', 'GO:0015074', 'GO:0004222', 'GO:0 ...

# %%
g = regulatory_gos #terminos padre
reg_gos = [] #guarda los gos hijos junto los padres

for i in g:
    superclass_nodes = nx.ancestors(knowledge_graph, i)
    superclass_nodes.add(i)
    super_graph = knowledge_graph.subgraph(superclass_nodes)
    nodes_info = nx.get_node_attributes(super_graph, 'NAME')
    n = [go for go in nodes_info.keys()]
    reg_gos.extend(n)
reg_gos = set(reg_gos)

# %%
### GO's regulatorios supuestos con el filtro de interpro
r = knowledge_graph.subgraph(regulatory_gos)
nx.get_node_attributes(r, 'NAME')
# Out:
# {'GO:0009401': 'name: phosphoenolpyruvate-dependent sugar phosphotransferase system',
#  'GO:0005981': 'name: regulation of glycogen catabolic process',
#  'GO:0009873': 'name: ethylene-activated signaling pathway',
#  'GO:0000978': 'name: RNA polymerase II cis-regulatory region sequence-specific DNA binding',
#  'GO:0007015': 'name: actin filament organization',
#  'GO:0043066': 'name: negative regulation of apoptotic process',
#  'GO:0042552': 'name: myelination',
#  'GO:1901894': 'name: regulation of ATPase-coupled calcium transmembrane transporter activity',
#  'GO:0003887': 'name: DNA-directed DNA polymerase activity',
#  'GO:0006468': 'name: protein phosphorylation',
#  'GO:1900025': 'name: negative regulation of substrate adhesion-dependent cell spreading',
#  'GO:0003896': 'name: DNA primase activity',
#  'GO:0000723': 'name: telomere maintenance',
#  'GO:0008233': 'name: peptidase activity',
#  'GO:0009960': 'name: endosperm development',
#  'GO:0043130': 'name: ubiquitin binding',
#  'GO:0070449': 'name: elongin complex',
#  'GO:0050709': 'name: negative regulation of protein secretion',
#  'GO:0006260': 'name: DNA replication',
#  'GO:0032266': 'name: phosphatidylinositol-3-phosphate binding',
#  'GO:0034315': 'name: regulation of Arp2/3 complex-mediated actin nucleation',
#  'GO:0010052': 'name: guard cell differentiation',
#  'GO:0000281': 'name: mitotic cytokinesis',
#  'GO:1990246': 'name: uniplex complex',
#  'GO:0051087': 'name: protein-folding chaperone binding',
#  'GO:0000124': 'name: SAGA complex',
#  'GO:0090560': 'name: 2-(3-amino-3-carboxypropyl)histidine synthase activity',
#  'GO:0001514': 'name: selenocysteine incorporation',
#  'GO:0006694': 'name: steroid biosynthetic process',
#  'GO:0005882': 'name: intermediate filament',
#  'GO:0008289': 'name: lipid binding',
#  'GO:0035226': 'name: glutamate-cysteine ligase catalytic subunit binding',
#  'GO:0008168': 'name: methyltransferase activity',
#  'GO:0010921': 'name: regulation of phosphatase activity',
#  'GO:0046689': 'name: response to mercury ion',
#  'GO:0005509': 'name: calcium ion binding',
#  'GO:0045182': 'name: translation regulator activity',
#  'GO:0004659': 'name: prenyltransferase activity',
#  'GO:0050434': 'name: positive regulation of viral transcription',
#  'GO:0070897': 'name: transcription preinitiation complex assembly',
#  'GO:0042128': 'name: nitrate assimilation',
#  'GO:0008270': 'name: zinc ion binding',
#  'GO:0005783': 'name: endoplasmic reticulum',
#  'GO:0035650': 'name: AP-1 adaptor complex binding',
#  'GO:0000166': 'name: nucleotide binding',
#  'GO:0016989': 'name: sigma factor antagonist activity',
#  'GO:0000156': 'name: phosphorelay response regulator activity',
#  'GO:0001070': 'name: RNA-binding transcription regulator activity',
#  'GO:0003684': 'name: damaged DNA binding',
#  'GO:0003714': 'name: transcription corepressor activity',
#  'GO:0000781': 'name: chromosome, telomeric region',
#  'GO:0006888': 'name: endoplasmic reticulum to Golgi vesicle-mediated transport',
#  'GO:0048578': 'name: positive regulation of long-day photoperiodism, flowering',
#  'GO:0006289': 'name: nucleotide-excision repair',
#  'GO:0045340': 'name: mercury ion binding',
#  'GO:0046278': 'name: 3,4-dihydroxybenzoate metabolic process',
#  'GO:0007283': 'name: spermatogenesis',
#  'GO:0006879': 'name: intracellular iron ion homeostasis',
#  'GO:0003676': 'name: nucleic acid binding',
#  'GO:0045087': 'name: innate immune response',
#  'GO:0016055': 'name: Wnt signaling pathway',
#  'GO:0000150': 'name: DNA strand exchange activity',
#  'GO:0005789': 'name: endoplasmic reticulum membrane',
#  'GO:0050262': 'name: ribosylnicotinamide kinase activity',
#  'GO:0019208': 'name: phosphatase regulator activity',
#  'GO:0004842': 'name: ubiquitin-protein transferase activity',
#  'GO:0090729': 'name: toxin activity',
#  'GO:0005672': 'name: transcription factor TFIIA complex',
#  'GO:0016575': 'name: histone deacetylation',
#  'GO:0004164': 'name: diphthine synthase activity',
#  'GO:0051560': 'name: mitochondrial calcium ion homeostasis',
#  'GO:0005085': 'name: guanyl-nucleotide exchange factor activity',
#  'GO:0006631': 'name: fatty acid metabolic process',
#  'GO:0019619': 'name: 3,4-dihydroxybenzoate catabolic process',
#  'GO:0005096': 'name: GTPase activator activity',
#  'GO:0006011': 'name: UDP-glucose metabolic process',
#  'GO:0051252': 'name: regulation of RNA metabolic process',
#  'GO:0006207': "name: 'de novo' pyrimidine nucleobase biosynthetic process",
#  'GO:0009750': 'name: response to fructose',
#  'GO:0008982': 'name: protein-N(PI)-phosphohistidine-sugar phosphotransferase activity',
#  'GO:0005634': 'name: nucleus',
#  'GO:0045893': 'name: positive regulation of DNA-templated transcription',
#  'GO:0043937': 'name: regulation of sporulation',
#  'GO:0000995': 'name: RNA polymerase III general transcription initiation factor activity',
#  'GO:0006357': 'name: regulation of transcription by RNA polymerase II',
#  'GO:0006750': 'name: glutathione biosynthetic process',
#  'GO:0000105': 'name: histidine biosynthetic process',
#  'GO:0035307': 'name: positive regulation of protein dephosphorylation',
#  'GO:0060340': 'name: positive regulation of type I interferon-mediated signaling pathway',
#  'GO:2000146': 'name: negative regulation of cell motility',
#  'GO:0031449': 'name: regulation of slow-twitch skeletal muscle fiber contraction',
#  'GO:0000155': 'name: phosphorelay sensor kinase activity',
#  'GO:0006402': 'name: mRNA catabolic process',
#  'GO:0070682': 'name: proteasome regulatory particle assembly',
#  'GO:0006366': 'name: transcription by RNA polymerase II',
#  'GO:0000921': 'name: septin ring assembly',
#  'GO:0071467': 'name: cellular response to pH',
#  'GO:0005525': 'name: GTP binding',
#  'GO:1901386': 'name: negative regulation of voltage-gated calcium channel activity',
#  'GO:0015940': 'name: pantothenate biosynthetic process',
#  'GO:0005739': 'name: mitochondrion',
#  'GO:0006276': 'name: plasmid maintenance',
#  'GO:0030527': 'name: structural constituent of chromatin',
#  'GO:0006952': 'name: defense response',
#  'GO:0050688': 'name: regulation of defense response to virus',
#  'GO:0099122': 'name: RNA polymerase II C-terminal domain binding',
#  'GO:0006325': 'name: chromatin organization',
#  'GO:0000164': 'name: protein phosphatase type 1 complex',
#  'GO:0046782': 'name: regulation of viral transcription',
#  'GO:0043231': 'name: intracellular membrane-bounded organelle',
#  'GO:0045122': 'name: aflatoxin biosynthetic process',
#  'GO:0000502': 'name: proteasome complex',
#  'GO:0000398': 'name: mRNA splicing, via spliceosome',
#  'GO:0006897': 'name: endocytosis',
#  'GO:0001227': 'name: DNA-binding transcription repressor activity, RNA polymerase II-specific',
#  'GO:0046983': 'name: protein dimerization activity',
#  'GO:0009909': 'name: regulation of flower development',
#  'GO:0006355': 'name: regulation of DNA-templated transcription',
#  'GO:0045116': 'name: protein neddylation',
#  'GO:0048869': 'name: cellular developmental process',
#  'GO:0032934': 'name: sterol binding',
#  'GO:0005615': 'name: extracellular space',
#  'GO:0045202': 'name: synapse',
#  'GO:0006109': 'name: regulation of carbohydrate metabolic process',
#  'GO:0070530': 'name: K63-linked polyubiquitin modification-dependent protein binding',
#  'GO:0005643': 'name: nuclear pore',
#  'GO:0005940': 'name: septin ring',
#  'GO:0009347': 'name: aspartate carbamoyltransferase complex',
#  'GO:0031554': 'name: regulation of termination of DNA-templated transcription',
#  'GO:0099106': 'name: ion channel regulator activity',
#  'GO:0019781': 'name: NEDD8 activating enzyme activity',
#  'GO:0031507': 'name: heterochromatin formation',
#  'GO:0051775': 'name: response to redox state',
#  'GO:0045892': 'name: negative regulation of DNA-templated transcription',
#  'GO:0002218': 'name: activation of innate immune response',
#  'GO:2000022': 'name: regulation of jasmonic acid mediated signaling pathway',
#  'GO:0006808': 'name: regulation of nitrogen utilization',
#  'GO:0000309': 'name: nicotinamide-nucleotide adenylyltransferase activity',
#  'GO:2001256': 'name: regulation of store-operated calcium entry',
#  'GO:0034243': 'name: regulation of transcription elongation by RNA polymerase II',
#  'GO:0005777': 'name: peroxisome',
#  'GO:0019299': 'name: rhamnose metabolic process',
#  'GO:0051726': 'name: regulation of cell cycle',
#  'GO:0031167': 'name: rRNA methylation',
#  'GO:0030915': 'name: Smc5-Smc6 complex',
#  'GO:0006959': 'name: humoral immune response',
#  'GO:0001965': 'name: G-protein alpha-subunit binding',
#  'GO:0000381': 'name: regulation of alternative mRNA splicing, via spliceosome',
#  'GO:0006310': 'name: DNA recombination',
#  'GO:0043087': 'name: regulation of GTPase activity',
#  'GO:0016151': 'name: nickel cation binding',
#  'GO:0005858': 'name: axonemal dynein complex',
#  'GO:0060090': 'name: molecular adaptor activity',
#  'GO:0006265': 'name: DNA topological change',
#  'GO:0000160': 'name: phosphorelay signal transduction system',
#  'GO:0000123': 'name: histone acetyltransferase complex',
#  'GO:0016032': 'name: viral process',
#  'GO:0009788': 'name: negative regulation of abscisic acid-activated signaling pathway',
#  'GO:0017183': 'name: protein histidyl modification to diphthamide',
#  'GO:0043158': 'name: heterocyst development',
#  'GO:0006383': 'name: transcription by RNA polymerase III',
#  'GO:0006284': 'name: base-excision repair',
#  'GO:0005956': 'name: protein kinase CK2 complex',
#  'GO:0006508': 'name: proteolysis',
#  'GO:0006282': 'name: regulation of DNA repair',
#  'GO:0006281': 'name: DNA repair',
#  'GO:0090537': 'name: CERF complex',
#  'GO:0048203': 'name: vesicle targeting, trans-Golgi to endosome',
#  'GO:0030234': 'name: enzyme regulator activity',
#  'GO:0019348': 'name: dolichol metabolic process',
#  'GO:0017025': 'name: TBP-class protein binding',
#  'GO:0010923': 'name: negative regulation of phosphatase activity',
#  'GO:0008984': 'name: protein-glutamate methylesterase activity',
#  'GO:0051606': 'name: detection of stimulus',
#  'GO:0003824': 'name: catalytic activity',
#  'GO:0019901': 'name: protein kinase binding',
#  'GO:0006384': 'name: transcription initiation at RNA polymerase III promoter',
#  'GO:0003950': 'name: NAD+ ADP-ribosyltransferase activity',
#  'GO:0003911': 'name: DNA ligase (NAD+) activity',
#  'GO:0007623': 'name: circadian rhythm',
#  'GO:0030145': 'name: manganese ion binding',
#  'GO:0005667': 'name: transcription regulator complex',
#  'GO:0016776': 'name: phosphotransferase activity, phosphate group as acceptor',
#  'GO:0004402': 'name: histone acetyltransferase activity',
#  'GO:0051537': 'name: 2 iron, 2 sulfur cluster binding',
#  'GO:0032007': 'name: negative regulation of TOR signaling',
#  'GO:0007420': 'name: brain development',
#  'GO:0048709': 'name: oligodendrocyte differentiation',
#  'GO:0044781': 'name: bacterial-type flagellum organization',
#  'GO:0004519': 'name: endonuclease activity',
#  'GO:0035556': 'name: intracellular signal transduction',
#  'GO:0030238': 'name: male sex determination',
#  'GO:0005944': 'name: phosphatidylinositol 3-kinase complex, class IB',
#  'GO:0035303': 'name: regulation of dephosphorylation',
#  'GO:0009399': 'name: nitrogen fixation',
#  'GO:0000774': 'name: adenyl-nucleotide exchange factor activity',
#  'GO:0010468': 'name: regulation of gene expression',
#  'GO:0008380': 'name: RNA splicing',
#  'GO:0008063': 'name: Toll signaling pathway',
#  'GO:0007275': 'name: multicellular organism development',
#  'GO:0003407': 'name: neural retina development',
#  'GO:0043248': 'name: proteasome assembly',
#  'GO:0045717': 'name: negative regulation of fatty acid biosynthetic process',
#  'GO:0016514': 'name: SWI/SNF complex',
#  'GO:0030182': 'name: neuron differentiation',
#  'GO:0048658': 'name: anther wall tapetum development',
#  'GO:0000226': 'name: microtubule cytoskeleton organization',
#  'GO:0009966': 'name: regulation of signal transduction',
#  'GO:0010045': 'name: response to nickel cation',
#  'GO:0005689': 'name: U12-type spliceosomal complex',
#  'GO:0003700': 'name: DNA-binding transcription factor activity',
#  'GO:0005524': 'name: ATP binding',
#  'GO:0030154': 'name: cell differentiation',
#  'GO:0045944': 'name: positive regulation of transcription by RNA polymerase II',
#  'GO:0000724': 'name: double-strand break repair via homologous recombination',
#  'GO:0043269': 'name: regulation of monoatomic ion transport',
#  'GO:0005829': 'name: cytosol',
#  'GO:2000031': 'name: regulation of salicylic acid mediated signaling pathway',
#  'GO:0032088': 'name: negative regulation of NF-kappaB transcription factor activity',
#  'GO:0030151': 'name: molybdenum ion binding',
#  'GO:0004674': 'name: protein serine/threonine kinase activity',
#  'GO:0046872': 'name: metal ion binding',
#  'GO:0004673': 'name: protein histidine kinase activity',
#  'GO:0040008': 'name: regulation of growth',
#  'GO:0007165': 'name: signal transduction',
#  'GO:0008907': 'name: integrase activity',
#  'GO:0032297': 'name: negative regulation of DNA-templated DNA replication initiation',
#  'GO:0016538': 'name: cyclin-dependent protein serine/threonine kinase regulator activity',
#  'GO:0021778': 'name: oligodendrocyte cell fate specification',
#  'GO:0006275': 'name: regulation of DNA replication',
#  'GO:0000159': 'name: protein phosphatase type 2A complex',
#  'GO:0010026': 'name: trichome differentiation',
#  'GO:0016799': 'name: hydrolase activity, hydrolyzing N-glycosyl compounds',
#  'GO:0008603': 'name: cAMP-dependent protein kinase regulator activity',
#  'GO:0016586': 'name: RSC-type complex',
#  'GO:0019217': 'name: regulation of fatty acid metabolic process',
#  'GO:0003899': "name: DNA-directed 5'-3' RNA polymerase activity",
#  'GO:0009378': 'name: four-way junction helicase activity',
#  'GO:0061522': 'name: 1,4-dihydroxy-2-naphthoyl-CoA thioesterase activity',
#  'GO:0009432': 'name: SOS response',
#  'GO:0042176': 'name: regulation of protein catabolic process',
#  'GO:0042981': 'name: regulation of apoptotic process',
#  'GO:0009330': 'name: DNA topoisomerase type II (double strand cut, ATP-hydrolyzing) complex',
#  'GO:0080009': 'name: mRNA methylation',
#  'GO:0009372': 'name: quorum sensing',
#  'GO:0005681': 'name: spliceosomal complex',
#  'GO:0071339': 'name: MLL1 complex',
#  'GO:0001817': 'name: regulation of cytokine production',
#  'GO:0046677': 'name: response to antibiotic',
#  'GO:0044325': 'name: transmembrane transporter binding',
#  'GO:0004222': 'name: metalloendopeptidase activity',
#  'GO:0003713': 'name: transcription coactivator activity',
#  'GO:0016722': 'name: oxidoreductase activity, acting on metal ions',
#  'GO:0003916': 'name: DNA topoisomerase activity',
#  'GO:0006525': 'name: arginine metabolic process',
#  'GO:0003746': 'name: translation elongation factor activity',
#  'GO:0000977': 'name: RNA polymerase II transcription regulatory region sequence-specific DNA binding',
#  'GO:0016540': 'name: protein autoprocessing',
#  'GO:0015485': 'name: cholesterol binding',
#  'GO:0051301': 'name: cell division',
#  'GO:0006367': 'name: transcription initiation at RNA polymerase II promoter',
#  'GO:0034246': 'name: mitochondrial transcription factor activity',
#  'GO:0042025': 'name: host cell nucleus',
#  'GO:0009507': 'name: chloroplast',
#  'GO:0047286': 'name: NAD+-diphthamide ADP-ribosyltransferase activity',
#  'GO:0019888': 'name: protein phosphatase regulator activity',
#  'GO:0042054': 'name: histone methyltransferase activity',
#  'GO:0071468': 'name: cellular response to acidic pH',
#  'GO:0032933': 'name: SREBP signaling pathway',
#  'GO:0000127': 'name: transcription factor TFIIIC complex',
#  'GO:0120020': 'name: cholesterol transfer activity',
#  'GO:0001216': 'name: DNA-binding transcription activator activity',
#  'GO:0019210': 'name: kinase inhibitor activity',
#  'GO:0031931': 'name: TORC1 complex',
#  'GO:0001932': 'name: regulation of protein phosphorylation',
#  'GO:0030127': 'name: COPII vesicle coat',
#  'GO:0005507': 'name: copper ion binding',
#  'GO:0005515': 'name: protein binding',
#  'GO:0005694': 'name: chromosome',
#  'GO:0003697': 'name: single-stranded DNA binding',
#  'GO:0016772': 'name: transferase activity, transferring phosphorus-containing groups',
#  'GO:0042254': 'name: ribosome biogenesis',
#  'GO:0008277': 'name: regulation of G protein-coupled receptor signaling pathway',
#  'GO:0071805': 'name: potassium ion transmembrane transport',
#  'GO:0006391': 'name: transcription initiation at mitochondrial promoter',
#  'GO:1990226': 'name: histone methyltransferase binding',
#  'GO:0006352': 'name: DNA-templated transcription initiation',
#  'GO:0019629': 'name: propionate catabolic process, 2-methylcitrate cycle',
#  'GO:0009890': 'name: negative regulation of biosynthetic process',
#  'GO:0000981': 'name: DNA-binding transcription factor activity, RNA polymerase II-specific',
#  'GO:0097367': 'name: carbohydrate derivative binding',
#  'GO:0003690': 'name: double-stranded DNA binding',
#  'GO:0000976': 'name: transcription cis-regulatory region binding',
#  'GO:0008324': 'name: monoatomic cation transmembrane transporter activity',
#  'GO:0006396': 'name: RNA processing',
#  'GO:0043565': 'name: sequence-specific DNA binding',
#  'GO:0003723': 'name: RNA binding',
#  'GO:0015689': 'name: molybdate ion transport',
#  'GO:0010090': 'name: trichome morphogenesis',
#  'GO:0009736': 'name: cytokinin-activated signaling pathway',
#  'GO:0004864': 'name: protein phosphatase inhibitor activity',
#  'GO:0006974': 'name: DNA damage response',
#  'GO:0016602': 'name: CCAAT-binding factor complex',
#  'GO:0019887': 'name: protein kinase regulator activity',
#  'GO:1900111': 'name: positive regulation of histone H3-K9 dimethylation',
#  'GO:0003712': 'name: transcription coregulator activity',
#  'GO:0016567': 'name: protein ubiquitination',
#  'GO:0006886': 'name: intracellular protein transport',
#  'GO:0099402': 'name: plant organ development',
#  'GO:0015074': 'name: DNA integration',
#  'GO:0046428': 'name: 1,4-dihydroxy-2-naphthoate octaprenyltransferase activity',
#  'GO:0006986': 'name: response to unfolded protein',
#  'GO:0045737': 'name: positive regulation of cyclin-dependent protein serine/threonine kinase activity',
#  'GO:0006406': 'name: mRNA export from nucleus',
#  'GO:0031124': "name: mRNA 3'-end processing",
#  'GO:0000062': 'name: fatty-acyl-CoA binding',
#  'GO:0031638': 'name: zymogen activation',
#  'GO:0004521': 'name: RNA endonuclease activity',
#  'GO:0006338': 'name: chromatin remodeling',
#  'GO:0009234': 'name: menaquinone biosynthetic process',
#  'GO:0019867': 'name: outer membrane',
#  'GO:0006817': 'name: phosphate ion transport',
#  'GO:0006935': 'name: chemotaxis',
#  'GO:0005952': 'name: cAMP-dependent protein kinase complex',
#  'GO:0000122': 'name: negative regulation of transcription by RNA polymerase II',
#  'GO:0005886': 'name: plasma membrane',
#  'GO:0004252': 'name: serine-type endopeptidase activity',
#  'GO:0009862': 'name: systemic acquired resistance, salicylic acid mediated signaling pathway',
#  'GO:0016020': 'name: membrane',
#  'GO:0009739': 'name: response to gibberellin',
#  'GO:0035198': 'name: miRNA binding',
#  'GO:0005254': 'name: chloride channel activity',
#  'GO:0031047': 'name: regulatory ncRNA-mediated gene silencing',
#  'GO:0008935': 'name: 1,4-dihydroxy-2-naphthoyl-CoA synthase activity',
#  'GO:0007008': 'name: outer mitochondrial membrane organization',
#  'GO:0045600': 'name: positive regulation of fat cell differentiation',
#  'GO:0043047': 'name: single-stranded telomeric DNA binding',
#  'GO:0008988': 'name: rRNA (adenine-N6-)-methyltransferase activity',
#  'GO:0070286': 'name: axonemal dynein complex assembly',
#  'GO:0009435': 'name: NAD biosynthetic process',
#  'GO:0016790': 'name: thiolester hydrolase activity',
#  'GO:0016571': 'name: histone methylation',
#  'GO:0001671': 'name: ATPase activator activity',
#  'GO:0003906': 'name: DNA-(apurinic or apyrimidinic site) endonuclease activity',
#  'GO:0003917': 'name: DNA topoisomerase type I (single strand cut, ATP-independent) activity',
#  'GO:0036444': 'name: calcium import into the mitochondrion',
#  'GO:0060962': 'name: regulation of ribosomal protein gene transcription by RNA polymerase II',
#  'GO:0001228': 'name: DNA-binding transcription activator activity, RNA polymerase II-specific',
#  'GO:0042372': 'name: phylloquinone biosynthetic process',
#  'GO:0030374': 'name: nuclear receptor coactivator activity',
#  'GO:0035658': 'name: Mon1-Ccz1 complex',
#  'GO:0008428': 'name: ribonuclease inhibitor activity',
#  'GO:0030289': 'name: protein phosphatase 4 complex',
#  'GO:0006874': 'name: intracellular calcium ion homeostasis',
#  'GO:0005838': 'name: proteasome regulatory particle',
#  'GO:0005164': 'name: tumor necrosis factor receptor binding',
#  'GO:0031348': 'name: negative regulation of defense response',
#  'GO:0000439': 'name: transcription factor TFIIH core complex',
#  'GO:0019902': 'name: phosphatase binding',
#  'GO:0009986': 'name: cell surface',
#  'GO:0006368': 'name: transcription elongation by RNA polymerase II',
#  'GO:0031929': 'name: TOR signaling',
#  'GO:0071595': 'name: Nem1-Spo7 phosphatase complex',
#  'GO:0006351': 'name: DNA-templated transcription',
#  'GO:0006302': 'name: double-strand break repair',
#  'GO:0046935': 'name: 1-phosphatidylinositol-3-kinase regulator activity',
#  'GO:0070824': 'name: SHREC complex',
#  'GO:0042023': 'name: DNA endoreduplication',
#  'GO:0045670': 'name: regulation of osteoclast differentiation',
#  'GO:0070063': 'name: RNA polymerase binding',
#  'GO:0030254': 'name: protein secretion by the type III secretion system',
#  'GO:0005737': 'name: cytoplasm',
#  'GO:0042826': 'name: histone deacetylase binding',
#  'GO:0003678': 'name: DNA helicase activity',
#  'GO:0006811': 'name: monoatomic ion transport',
#  'GO:0006268': 'name: DNA unwinding involved in DNA replication',
#  'GO:0000139': 'name: Golgi membrane',
#  'GO:0000126': 'name: transcription factor TFIIIB complex',
#  'GO:0033209': 'name: tumor necrosis factor-mediated signaling pathway',
#  'GO:0006813': 'name: potassium ion transport',
#  'GO:0010506': 'name: regulation of autophagy',
#  'GO:0004523': 'name: RNA-DNA hybrid ribonuclease activity',
#  'GO:0003677': 'name: DNA binding',
#  'GO:0006270': 'name: DNA replication initiation'}

# %%
regulatory_graph = knowledge_graph.subgraph(regulatory_gos)
regulatory_graph.number_of_nodes()
reg_gos_info = nx.get_node_attributes(regulatory_graph, 'NAME')
reg_gos_namespaces = Counter(reg_gos_info.values())
reg_gos_namespaces_per = {name:(count/len(reg_gos_info)*100) for name, count in reg_gos_namespaces.items()}
# Out:
# {'biological_process': 52.34375,
#  'molecular_function': 33.33333333333333,
#  'cellular_component': 14.322916666666666}

# %%
#ploteando datos
keys = list(reg_gos_namespaces_per.keys())
vals = [float(reg_gos_namespaces_per[k]) for k in keys]
plt.ylabel('%')
plt.xlabel('Namespace')
sns.barplot(x=keys, y=vals, palette=sns.color_palette("magma")).set_title("Namespace percentage")
plt.show()

# %%
# go = 'GO:0019619'
superclass_nodes = nx.descendants(knowledge_graph, regulatory_gos)
superclass_nodes.add(go)
super_graph = knowledge_graph.subgraph(superclass_nodes)
nodes_info = nx.get_node_attributes(super_graph, 'NAME')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 # go = 'GO:0019619'
# ----> 2 superclass_nodes = nx.descendants(knowledge_graph, regulatory_gos)
#       3 superclass_nodes.add(go)
#       4 super_graph = knowledge_graph.subgraph(superclass_nodes)
#
# File c:\Users\enb09\miniconda3\envs\py3EduardoFL\lib\site-packages\networkx\classes\backends.py:148, in _dispatch.<locals>.wrapper(*args, **kwds)
#     144         else:
#     145             raise NetworkXNotImplemented(
#     146                 f"'{name}' not implemented by {plugin_name}"
#     147             )
# --> 148 return func(*args, **kwds)
#
# File c:\Users\enb09\miniconda3\envs\py3EduardoFL\lib\site-packages\networkx\algorithms\dag.py:73, in descendants(G, source)
#      39 @nx._dispatch
#      40 def descendants(G, source):
#      41     """Returns all nodes reachable from `source` in `G`.
#      42
#      43     Parameters
#    (...)
#      71     ancestors
#      72     """
# ---> 73     return {child for parent, child in nx.bfs_edges(G, source)}
#
# File c:\Users\enb09\miniconda3\envs\py3EduardoFL\lib\site-packages\networkx\algorithms\dag.py:73, in <setcomp>(.0)
#      39 @nx._dispatch
#      40 def descendants(G, source):
#      41     """Returns all nodes reachable from `source` in `G`.
#      42
#      43     Parameters
#    (...)
#      71     ancestors
#      72     """
# ---> 73     return {child for parent, child in nx.bfs_edges(G, source)}
#
# File c:\Users\enb09\miniconda3\envs\py3EduardoFL\lib\site-packages\networkx\algorithms\traversal\breadth_first_search.py:170, in bfs_edges(G, source, reverse, depth_limit, sort_neighbors)
#     168 else:
#     169     successors = G.neighbors
# --> 170 yield from generic_bfs_edges(G, source, successors, depth_limit, sort_neighbors)
#
# File c:\Users\enb09\miniconda3\envs\py3EduardoFL\lib\site-packages\networkx\algorithms\traversal\breadth_first_search.py:74, in generic_bfs_edges(G, source, neighbors, depth_limit, sort_neighbors)
#      71     _neighbors = neighbors
#      72     neighbors = lambda node: iter(sort_neighbors(_neighbors(node)))
# ---> 74 visited = {source}
#      75 if depth_limit is None:
#      76     depth_limit = len(G)
#
# TypeError: unhashable type: 'list'

# %%
from matplotlib import pyplot as plt
pos = nx.spring_layout(super_graph)
node_labels = nx.get_node_attributes(super_graph, 'NAME')

n = {got:name for got, name in nx.get_node_attributes(super_graph, 'NAME').items() if got != go}
n
# Out:
# {'GO:0042537': 'biological_process',
#  'GO:0018958': 'biological_process',
#  'GO:1901360': 'biological_process',
#  'GO:0043436': 'biological_process',
#  'GO:0071704': 'biological_process',
#  'GO:0044281': 'biological_process',
#  'GO:0008152': 'biological_process',
#  'GO:0006725': 'biological_process',
#  'GO:0019439': 'biological_process',
#  'GO:0072329': 'biological_process',
#  'GO:1901615': 'biological_process',
#  'GO:1901361': 'biological_process',
#  'GO:0016054': 'biological_process',
#  'GO:0019336': 'biological_process',
#  'GO:0019752': 'biological_process',
#  'GO:1901575': 'biological_process',
#  'GO:1901616': 'biological_process',
#  'GO:0019614': 'biological_process',
#  'GO:0044248': 'biological_process',
#  'GO:0009987': 'biological_process',
#  'GO:0044237': 'biological_process',
#  'GO:0009712': 'biological_process',
#  'GO:0046395': 'biological_process',
#  'GO:0046278': 'biological_process',
#  'GO:0008150': 'biological_process',
#  'GO:0044282': 'biological_process',
#  'GO:0032787': 'biological_process',
#  'GO:0009056': 'biological_process',
#  'GO:0006082': 'biological_process'}

# %%
nx.draw(super_graph, pos=graphviz_layout(super_graph, prog="dot"), with_labels=True, arrows=True)
